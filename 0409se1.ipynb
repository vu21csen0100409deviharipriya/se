# %%
----numpy

# %%
import numpy as np
arr = np.array([1, 2, 3, 4, 5])
arr_squared = np.square(arr)
print(arr_squared)
# Out:
# [ 1  4  9 16 25]

# %%
-----pandas

# %%
import pandas as pd

data = {'Name': ['Hari', 'Vamsi', 'Nishi'], 'Age': [25, 22, 31]}
df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age
# 0   Hari   25
# 1  Vamsi   22
# 2  Nishi   31

# %%
------matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

time = np.arange(0, 24, 1) 
temperature = np.random.uniform(20, 30, 24) 
humidity = np.random.uniform(40, 60, 24) 


plt.figure(figsize=(10, 5))
plt.plot(time, temperature, label='Temperature', marker='o', linestyle='-', color='red')

plt.title('Temperature and Humidity Over Time')
plt.xlabel('Time (hours)')
plt.ylabel('Temperature (°C)')

plt.legend()

plt.show()

plt.figure(figsize=(10, 5))
plt.plot(time, humidity, label='Humidity', marker='s', linestyle='-', color='blue')

plt.title('Temperature and Humidity Over Time')
plt.xlabel('Time (hours)')
plt.ylabel('Humidity (%)')

plt.legend()

plt.show()

# %%
1. Implement weather modeling* using the quadratic solution in stages:
hard-coding variables keyboard input,
read from a file, 
for a single set of input, 
multiple sets of inputs. 
a. save all versions, debug, fix problems, create a Github account

# %%
a----- hard coding variables

# %%
import matplotlib.pyplot as plt
import numpy as np

# Hard-coded coefficients for the quadratic equation (ax^2 + bx + c)
a = 0.1
b = -2
c = 10

# Generate x values (days)
days = np.arange(1, 31, 1)

# Calculate y values using the quadratic equation
temperature = a * days**2 + b * days + c

# Plot the graph
plt.plot(days, temperature, label='Weather Model')

# Add labels and title
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Quadratic Weather Model')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
b-----take input from user

# %%
import matplotlib.pyplot as plt
import numpy as np

def generate_weather_plot(days, temp_coefficient, rain_coefficient, initial_temp, initial_rain, label):
    days_array = np.arange(1, int(days) + 1)
    temperature = initial_temp - temp_coefficient * (days_array - 1) ** 2
    rainfall = initial_rain + rain_coefficient * (days_array - 1) ** 2

    plt.plot(days_array, temperature, label=f'Temperature {label}')
    plt.plot(days_array, rainfall, label=f'Rainfall {label}')

def main():
    # Predefined sets of values as a list of lists
    parameter_sets = [
        [10, 2.5, 0.5, 25.0, 5.0],
        [15, 3.0, 0.6, 22.0, 7.0],
        # Add more sets as needed
    ]

    # Process each set of parameters
    for i, parameters in enumerate(parameter_sets):
        generate_weather_plot(*parameters, label=f'Set {i + 1}')

    # Adding labels and title
    plt.xlabel('Days')
    plt.ylabel('Value')
    plt.title('Weather Modeling with Quadratic Solution')
    plt.legend()

    # Displaying the plot
    plt.show()

if __name__ == "__main__":
    main()

# %%
c-----read from a file

# %%
import matplotlib.pyplot as plt
import numpy as np

# Read coefficients from a text file
with open('coefficients.txt', 'r') as file:
    a, b, c = map(int, file.readline().strip().split())

# Generate x values (days)
days = np.arange(1, 31, 1)

# Calculate y values using the quadratic equation
temperature = a * days**2 + b * days + c

# Plot the graph
plt.plot(days, temperature, label='Weather Model')

# Add labels and title
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Quadratic Weather Model')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
d----single set of inputs

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predefined coefficients
coefficients = [3, 4, 1]

# Unpack coefficients
a, b, c = coefficients

# Generate x values (days)
days = np.arange(1, 31, 1)

# Calculate y values using the quadratic equation
temperature = a * days**2 + b * days + c

# Plot the graph
plt.plot(days, temperature, label='Weather Model')

# Add labels and title
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Quadratic Weather Model')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
e----multiple se of inputs

# %%
import matplotlib.pyplot as plt
import numpy as np

# Predefined sets of coefficients as a list of lists
coefficient_sets = [
    [3, 4, 1],
    [2, -3, 1],
    # Add more sets as needed
]

# Process each set of coefficients
for i, coefficients in enumerate(coefficient_sets):
    a, b, c = coefficients

    # Generate x values (days)
    days = np.arange(1, 31, 1)

    # Calculate y values using the quadratic equation
    temperature = a * days**2 + b * days + c

    # Plot the graph
    plt.plot(days, temperature, label=f'Weath Model - Set {i + 1}')

# Add labels and title
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Quadratic Weather Model')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
